# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
print(df['Age'].value_counts())
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
df["Age"]=df['Age'].fillna(df["Age"].mean())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
print(df['Sex'].value_counts())
print(df[df['Sex']=="female"]['Survived'].value_counts())
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64
# 1    233
# 0     81
# Name: Survived, dtype: int64

# %%
plt.figure (figsize=[8,5])
plt.title('Survived',fontdict={'fontsize':36,'fontweight':'bold'})
#sns.countplot(df["Sex"])
#sns.countplot(df["Sex"],hue=df['Survived'],data=df)
sns.countplot(data=df,x='Sex',hue=df['Survived'])
plt.xlabel('Gender')
plt.show()

# %%
df['Age'].describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
plt.figure(figsize=[18,8])
plt.title('Survived',fontdict={'fontsize':36,'fontweight':'bold'})
sns.histplot(x='Age',data=df)
# Out:
# <Axes: title={'center': 'Survived'}, xlabel='Age', ylabel='Count'>

# %%
#Filter the data 
female_survived_age_above_31=df[(df["Sex"]=="female") & (df["Survived"]==1) & (df["Age"]>18) & (df["Age"]<65)]

#Count the number of passengers
count=female_survived_age_above_31

print ("Number of Female Passenger Who survived & were older than 31;",count)
# Out:
# Number of Female Passenger Who survived & were older than 31;      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %%
#filter the data
male_survived_age_above_31=df[(df["Sex"]=="male") & (df["Survived"]==1) & (df["Age"]>18) & (df["Age"]<65)]

#Count the number of passengers
count=male_survived_age_above_31

print (count)
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex  \
# 17            18         1       2  Williams, Mr. Charles Eugene  male
# 21            22         1       2         Beesley, Mr. Lawrence  male
# 23            24         1       1  Sloper, Mr. William Thompson  male
# 36            37         1       3              Mamee, Mr. Hanna  male
# 55            56         1       1             Woolner, Mr. Hugh  male
# ..           ...       ...     ...                           ...   ...
# 828          829         1       3  McCormack, Mr. Thomas Joseph  male
# 838          839         1       3               Chip, Mr. Chang  male
# 839          840         1       1          Marechal, Mr. Pierre  male
# 857          858         1       1        Daly, Mr. Peter Denis   male
# 889          890         1       1         Behr, Mr. Karl Howell  male
#
#            Age  SibSp  Parch  Ticket     Fare Embarked
# 17   29.699118      0      0  244373  13.0000        S
# ...

# %%
#count the number of female passengers who survived & were older than 18
female_count=female_survived_age_above_31.shape[0]

#count the number of female passengers who survived & were older than 18
male_count=male_survived_age_above_31.shape[0]

#prepare data for plotting 
counts=pd.DataFrame({
    'Sex':['Female','Male'],
    'Survived_Age_Above_31':[female_count,male_count]
})

#Create a bar plot 
plt.figure(figsize=(8,6))
sns.barplot(x='Sex',y='Survived_Age_Above_31',data=counts,palette='viridis')
plt.title('Number of Passengers Who Survived & Were Older than 18')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.Show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 19
#      17 plt.xlabel('Sex')
#      18 plt.ylabel('Count')
# ---> 19 plt.Show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'Show'

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
max=df['Fare'].max()
print(max)
# Out:
# 512.3292

# %%
min=df['Fare'].min()
print(min)
# Out:
# 0.0

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
order=df[('Fare')].value_counts(ascending=False)
print(order.count())
a=order.iloc[1]
print(a)
# Out:
# 248
# 42
